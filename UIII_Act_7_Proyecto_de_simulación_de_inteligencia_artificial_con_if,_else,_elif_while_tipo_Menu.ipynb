# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisGuzman128/UIII-Act-7-Proyecto-de-simulaci-n-de-inteligencia-artificial-con-if-else-elif-while-tipo-Menu/blob/main/UIII_Act_7_Proyecto_de_simulaci%C3%B3n_de_inteligencia_artificial_con_if%2C_else%2C_elif_while_tipo_Menu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # programador
# # NL 27
# # Axel Guzman

# %%
# 19/mayo/2026

# Programador:
# Lenguaje de programación, experiencia,
# tipo de proyecto, nivel de dificultad,
# recomendación de IA y estado del proyecto.

# ======================================================
# 💻 CBTis 128
# 📚 Programación Orientada a Objetos 2026
# 🤖 Especialidad: Inteligencia Artificial
# 👨‍🏫 Docente: Manuel Nava
# 👨‍🎓 Alumno: Axel Guzman NL = 27
# 💻 Proyecto: Simulación de Inteligencia Artificial
# ======================================================

print("=========== SISTEMA IA PROGRAMADOR ===========")

nombre = input("Ingresa nombre del programador: ")
lenguaje = input("Ingresa lenguaje de programación: ")
experiencia = int(input("Ingresa años de experiencia: "))
proyecto = input("Ingresa tipo de proyecto: ")
dificultad = input("Ingresa nivel de dificultad (bajo, medio, alto): ")

print("\n=========== ANALISIS IA ===========")

# --------------------------------------------------
# Uso de while
# --------------------------------------------------

while experiencia < 0:
    print("⚠️ La experiencia no puede ser negativa")
    experiencia = int(input("Ingresa nuevamente los años de experiencia: "))

# --------------------------------------------------
# Uso de if
# --------------------------------------------------

if experiencia >= 5:
    print("💻 Programador con experiencia avanzada")

# --------------------------------------------------
# Uso de if else
# --------------------------------------------------

if dificultad == "alto":
    print("⚠️ Proyecto complejo")
else:
    print("✅ Proyecto manejable")

# --------------------------------------------------
# Uso de if elif else
# --------------------------------------------------

if lenguaje == "python":
    print("🤖 IA recomienda Machine Learning")

elif lenguaje == "java":
    print("☕ IA recomienda aplicaciones empresariales")

elif lenguaje == "javascript":
    print("🌐 IA recomienda desarrollo web")

else:
    print("💻 Lenguaje válido para programación general")

# --------------------------------------------------
# Operadores lógicos y relacionales
# --------------------------------------------------

if experiencia >= 3 and dificultad == "alto":
    print("🔥 IA detecta programador apto para proyectos complejos")

elif experiencia < 3 or dificultad == "medio":
    print("📚 IA recomienda seguir practicando programación")

# --------------------------------------------------
# Resultado final
# --------------------------------------------------

print("\n=========== RESULTADO FINAL ===========")

print("👨‍💻 Programador:", nombre)
print("🖥️ Lenguaje:", lenguaje)
print("📂 Proyecto:", proyecto)

if proyecto == "videojuego":
    print("🎮 Estado del proyecto: Desarrollo creativo")

elif proyecto == "pagina web":
    print("🌐 Estado del proyecto: Desarrollo web")

elif proyecto == "app movil":
    print("📱 Estado del proyecto: Aplicación móvil")

else:
    print("💻 Estado del proyecto: Proyecto general")

print("\n✅ Simulación de inteligencia artificial finalizada")
# Out:
# =========== SISTEMA IA PROGRAMADOR ===========
# Ingresa nombre del programador: Axel
# Ingresa lenguaje de programación: python
# Ingresa años de experiencia: 6
# Ingresa tipo de proyecto: videojuego
# Ingresa nivel de dificultad (bajo, medio, alto): alto
#
# =========== ANALISIS IA ===========
# 💻 Programador con experiencia avanzada
# ⚠️ Proyecto complejo
# 🤖 IA recomienda Machine Learning
# 🔥 IA detecta programador apto para proyectos complejos
#
# =========== RESULTADO FINAL ===========
# 👨‍💻 Programador: Axel
# 🖥️ Lenguaje: python
# 📂 Proyecto: videojuego
# 🎮 Estado del proyecto: Desarrollo creativo
#
# ✅ Simulación de inteligencia artificial finalizada

# %%
# 19/mayo/2026

# Programador:
# Lenguaje de programación, experiencia,
# tipo de proyecto, nivel de dificultad,
# recomendación de IA y estado del proyecto.

# ======================================================
# 💻 CBTis 128
# 📚 Programación Orientada a Objetos 2026
# 🤖 Especialidad: Inteligencia Artificial
# 👨‍🏫 Docente: Manuel Nava
# 👨‍🎓 Alumno: Axel Guzman NL = 27
# 💻 Proyecto: Simulación de Inteligencia Artificial
# ======================================================

print("=========== SISTEMA IA PROGRAMADOR ===========")

nombre = input("Ingresa nombre del programador: ")
lenguaje = input("Ingresa lenguaje de programación: ")
experiencia = int(input("Ingresa años de experiencia: "))
proyecto = input("Ingresa tipo de proyecto: ")
dificultad = input("Ingresa nivel de dificultad (bajo, medio, alto): ")

print("\n=========== ANALISIS IA ===========")

# --------------------------------------------------
# Uso de while
# --------------------------------------------------

while experiencia < 0:
    print("⚠️ La experiencia no puede ser negativa")
    experiencia = int(input("Ingresa nuevamente los años de experiencia: "))

# --------------------------------------------------
# Uso de if
# --------------------------------------------------

if experiencia >= 5:
    print("💻 Programador con experiencia avanzada")

# --------------------------------------------------
# Uso de if else
# --------------------------------------------------

if dificultad == "alto":
    print("⚠️ Proyecto complejo")
else:
    print("✅ Proyecto manejable")

# --------------------------------------------------
# Uso de if elif else
# --------------------------------------------------

if lenguaje == "python":
    print("🤖 IA recomienda Machine Learning")

elif lenguaje == "java":
    print("☕ IA recomienda aplicaciones empresariales")

elif lenguaje == "javascript":
    print("🌐 IA recomienda desarrollo web")

else:
    print("💻 Lenguaje válido para programación general")

# --------------------------------------------------
# Operadores lógicos y relacionales
# --------------------------------------------------

if experiencia >= 3 and dificultad == "alto":
    print("🔥 IA detecta programador apto para proyectos complejos")

elif experiencia < 3 or dificultad == "medio":
    print("📚 IA recomienda seguir practicando programación")

# --------------------------------------------------
# Resultado final
# --------------------------------------------------

print("\n=========== RESULTADO FINAL ===========")

print("👨‍💻 Programador:", nombre)
print("🖥️ Lenguaje:", lenguaje)
print("📂 Proyecto:", proyecto)

if proyecto == "videojuego":
    print("🎮 Estado del proyecto: Desarrollo creativo")

elif proyecto == "pagina web":
    print("🌐 Estado del proyecto: Desarrollo web")

elif proyecto == "app movil":
    print("📱 Estado del proyecto: Aplicación móvil")

else:
    print("💻 Estado del proyecto: Proyecto general")

print("\n✅ Simulación de inteligencia artificial finalizada")
# Out:
# =========== SISTEMA IA PROGRAMADOR ===========
# Ingresa nombre del programador: marco
# Ingresa lenguaje de programación: java
# Ingresa años de experiencia: 2
# Ingresa tipo de proyecto: pagina web
# Ingresa nivel de dificultad (bajo, medio, alto): medio
#
# =========== ANALISIS IA ===========
# ✅ Proyecto manejable
# ☕ IA recomienda aplicaciones empresariales
# 📚 IA recomienda seguir practicando programación
#
# =========== RESULTADO FINAL ===========
# 👨‍💻 Programador: marco
# 🖥️ Lenguaje: java
# 📂 Proyecto: pagina web
# 🌐 Estado del proyecto: Desarrollo web
#
# ✅ Simulación de inteligencia artificial finalizada

# %%
# 19/mayo/2026

# Programador:
# Lenguaje de programación, experiencia,
# tipo de proyecto, nivel de dificultad,
# recomendación de IA y estado del proyecto.

# ======================================================
# 💻 CBTis 128
# 📚 Programación Orientada a Objetos 2026
# 🤖 Especialidad: Inteligencia Artificial
# 👨‍🏫 Docente: Manuel Nava
# 👨‍🎓 Alumno: Axel Guzman NL = 27
# 💻 Proyecto: Simulación de Inteligencia Artificial
# ======================================================

print("=========== SISTEMA IA PROGRAMADOR ===========")

nombre = input("Ingresa nombre del programador: ")
lenguaje = input("Ingresa lenguaje de programación: ")
experiencia = int(input("Ingresa años de experiencia: "))
proyecto = input("Ingresa tipo de proyecto: ")
dificultad = input("Ingresa nivel de dificultad (bajo, medio, alto): ")

print("\n=========== ANALISIS IA ===========")

# --------------------------------------------------
# Uso de while
# --------------------------------------------------

while experiencia < 0:
    print("⚠️ La experiencia no puede ser negativa")
    experiencia = int(input("Ingresa nuevamente los años de experiencia: "))

# --------------------------------------------------
# Uso de if
# --------------------------------------------------

if experiencia >= 5:
    print("💻 Programador con experiencia avanzada")

# --------------------------------------------------
# Uso de if else
# --------------------------------------------------

if dificultad == "alto":
    print("⚠️ Proyecto complejo")
else:
    print("✅ Proyecto manejable")

# --------------------------------------------------
# Uso de if elif else
# --------------------------------------------------

if lenguaje == "python":
    print("🤖 IA recomienda Machine Learning")

elif lenguaje == "java":
    print("☕ IA recomienda aplicaciones empresariales")

elif lenguaje == "javascript":
    print("🌐 IA recomienda desarrollo web")

else:
    print("💻 Lenguaje válido para programación general")

# --------------------------------------------------
# Operadores lógicos y relacionales
# --------------------------------------------------

if experiencia >= 3 and dificultad == "alto":
    print("🔥 IA detecta programador apto para proyectos complejos")

elif experiencia < 3 or dificultad == "medio":
    print("📚 IA recomienda seguir practicando programación")

# --------------------------------------------------
# Resultado final
# --------------------------------------------------

print("\n=========== RESULTADO FINAL ===========")

print("👨‍💻 Programador:", nombre)
print("🖥️ Lenguaje:", lenguaje)
print("📂 Proyecto:", proyecto)

if proyecto == "videojuego":
    print("🎮 Estado del proyecto: Desarrollo creativo")

elif proyecto == "pagina web":
    print("🌐 Estado del proyecto: Desarrollo web")

elif proyecto == "app movil":
    print("📱 Estado del proyecto: Aplicación móvil")

else:
    print("💻 Estado del proyecto: Proyecto general")

print("\n✅ Simulación de inteligencia artificial finalizada")
# Out:
# =========== SISTEMA IA PROGRAMADOR ===========
# Ingresa nombre del programador: josafat
# Ingresa lenguaje de programación: javascript
# Ingresa años de experiencia: 4
# Ingresa tipo de proyecto: app movil
# Ingresa nivel de dificultad (bajo, medio, alto): bajo
#
# =========== ANALISIS IA ===========
# ✅ Proyecto manejable
# 🌐 IA recomienda desarrollo web
#
# =========== RESULTADO FINAL ===========
# 👨‍💻 Programador: josafat
# 🖥️ Lenguaje: javascript
# 📂 Proyecto: app movil
# 📱 Estado del proyecto: Aplicación móvil
#
# ✅ Simulación de inteligencia artificial finalizada

# %% [markdown]
# ![texto del enlace](https://raw.githubusercontent.com/LuisGuzman128/UIII-Act-7-Proyecto-de-simulaci-n-de-inteligencia-artificial-con-if-else-elif-while-tipo-Menu/refs/heads/main/infografia.png)
